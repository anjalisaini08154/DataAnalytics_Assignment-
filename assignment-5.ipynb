# %% [markdown]
# # **Assignment 5**

# %% [markdown]
# 1.	Sales Data Analysis Dashboard

# %% [markdown]
# ![sales_data.png](attachment:sales_data.png)

# %% [markdown]
# •	The dashboard shows that sales are heavily concentrated in the North region, contributing nearly all of the total sales. The overall sales amount is approximately 1.37M, indicating strong performance. The discount value is relatively low (around 39.93), suggesting limited price reductions. Overall, sales are not evenly distributed and are dominated by a single region

# %% [markdown]
# 2. Fraud Detection Analysis Dashboard

# %% [markdown]
# ![Faurd Detection Analysis.png](<attachment:Faurd Detection Analysis.png>)

# %% [markdown]
# •	The visualization shows that the Time variable dominates the dataset, indicating a strong trend or accumulation over time. The total transaction amount is also high (around 25.16M), reflecting significant financial activity. In contrast, variables like V1 have negligible values, suggesting they contribute very little compared to other features.
